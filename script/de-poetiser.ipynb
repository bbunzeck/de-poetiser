# %% [markdown]
# # De-poetiser
#
# A jupyter notebook that de-poetises texts by replacing words with random synonyms from WordNet, effectively destroying rhymes, rhythm, and changing connotation, metaphors and analogies.

# %% [markdown]
# ## Prerequisites
#
# NLTK and the included [WordNet Corpus](https://wordnet.princeton.edu/) need to be installed

# %%
import nltk
import random
from nltk.corpus import wordnet, stopwords

# %% [markdown]
# ## De-poetisation
#
# The text sample is the first chapter of The Great Gatsby.

# %%
f = open('input.txt', 'r')
content = f.read()
print(content)
# Out:
# In my younger and more vulnerable years my father gave me some advice
# that I've been turning over in my mind ever since.
#
# "Whenever you feel like criticizing any one," he told me, "just
# remember that all the people in this world haven't had the advantages
# that you've had."
#
# He didn't say any more but we've always been unusually communicative
# in a reserved way, and I understood that he meant a great deal more
# than that. In consequence I'm inclined to reserve all judgments,
# a habit that has opened up many curious natures to me and also
# made me the victim of not a few veteran bores. The abnormal mind
# is quick to detect and attach itself to this quality when it
# appears in a normal person, and so it came about that in college I
# was unjustly accused of being a politician, because I was privy to the
# secret griefs of wild, unknown men. Most of the confidences were
# unsought--frequently I have feigned sleep, preoccupation, or a hostile
# ...

# %%
words = content.split()
new_content = list()
for word in words:
    if word in stopwords.words('english'):
        new_content.append(word)
    else:
        syn = list()
        for synset in wordnet.synsets(word):
            for lemma in synset.lemmas():
                syn.append(lemma.name())
        if len(syn) > 0:
            new_content.append(random.choice(syn))
        else:
            new_content.append(word)
separator = ' '
output = separator.join(new_content)

# %%
output
# Out:
# 'indium my jr. and more vulnerable year my Father pass_on me some advice that I\'ve been turn over in my mind of_all_time since. "Whenever you experience the_like criticise any one," he severalize me, "just commend that all the the_great_unwashed in this world haven\'t had the advantage that you\'ve had." he didn\'t tell any more but we\'ve invariably been unusually communicative in a reserve way, and unity translate that he have_in_mind a keen deal more than that. in effect I\'m incline to reserve all judgments, a substance_abuse that has open up many queer nature to me and also have me the victim of not a few seasoned bores. The abnormal mind is prompt to detect and impound itself to this choice when it seem in a normal person, and so it come about that in college single was unjustly accuse of being a politician, because I was earth-closet to the secret grief of wild, unsung men. most of the confidence were unsought--frequently i have assume sleep, preoccupation, or a hostile levit
# ...

# %% [markdown]
# ## Future improvements
#
# POS-tagging, punctuation handling, etc.
